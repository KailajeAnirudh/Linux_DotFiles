# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv(r'xf-n2415-il-200000.csv', header=9)

# %%
df
# Out:
#      Alpha      Cl       Cd      Cdp      Cm  Top_Xtr  Bot_Xtr
# 0   -14.25 -0.7841  0.07840  0.07388 -0.0595   1.0000   0.0563
# 1   -14.00 -0.8778  0.06085  0.05586 -0.0730   1.0000   0.0548
# 2   -13.75 -0.9147  0.05409  0.04880 -0.0764   1.0000   0.0547
# 3   -13.50 -0.9374  0.04984  0.04432 -0.0769   1.0000   0.0549
# 4   -13.25 -0.9551  0.04665  0.04090 -0.0758   1.0000   0.0553
# ..     ...     ...      ...      ...     ...      ...      ...
# 130  18.25  1.3168  0.09228  0.08633  0.0050   0.0493   1.0000
# 131  18.50  1.2992  0.09830  0.09260  0.0023   0.0488   1.0000
# 132  18.75  1.2802  0.10481  0.09935 -0.0008   0.0483   1.0000
# 133  19.00  1.2592  0.11193  0.10670 -0.0045   0.0479   1.0000
# 134  19.25  1.2332  0.12028  0.11530 -0.0093   0.0476   1.0000
#
# [135 rows x 7 columns]

# %%
fig = plt.figure()
# plt.plot(df.Alpha, df.Cl, label='C_L')
plt.plot(df.Alpha, df.Cm, label='C_D')
plt.show()

# %%
df2 = df.loc[:, ['Alpha', 'Cl', 'Cm']]
alpha_0_uu = df2.iloc[abs(df2.Cl.to_numpy()).argmin()].Alpha
df2.Alpha -= alpha_0_uu*2
alpha_0_ud = -alpha_0_uu
df2.Cm *= -1

# %%
fig = plt.figure()
plt.plot(df2.Alpha, df2.Cl, label='C_L_ud')
plt.plot(df.Alpha, df.Cl, label='C_l_uu')
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')
plt.axvline(alpha_0_ud, color='red', linestyle='--')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
alpha_0
# Out:
# -2.25

# %%
# %matplotlib widget
fig = plt.figure()
plt.plot(df.Alpha, df2.Cm, label='C_m_ud')
plt.axvline(alpha_0_ud, color='red', linestyle='--')
plt.axhline(0, color='black', linestyle='--')
plt.axhline(df2[df.Alpha == alpha_0_ud]['Cm'].values[0], color='green', linestyle='--')

# Add text value of y for the green horizontal line
plt.text(0, df2[df.Alpha == alpha_0_ud]['Cm'].values[0], str(df2[df.Alpha == alpha_0_ud]['Cm'].values[0]), color='green')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
#       2 fig = plt.figure()
# ----> 3 plt.plot(df.Alpha, df2.Cm, label='C_m_ud')
#       4 plt.axvline(alpha_0_ud, color='red', linestyle='--')
#       5 plt.axhline(0, color='black', linestyle='--')
#
# NameError: name 'df' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df2[df2.Alpha == alpha_0_ud]['Cm'].values[0]
# Out:
# 0.0569

# %%
df2.iloc[abs(df2.Cm.to_numpy()).argmin()].Alpha
# Out:
# 17.0

# %%
image = r'Screenshot from 2024-02-10 16-58-31.png'
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# FILEPATH: /home/anirudhkailaje/Documents/01_UPenn/05_MEAM5430/02_Homework2/AerofoilData.ipynb
image = r'Screenshot from 2024-02-10 16-58-31.png'
fig = plt.figure()
img = mpimg.imread(image)
plt.imshow(img)
plt.axis('off')
plt.show()
