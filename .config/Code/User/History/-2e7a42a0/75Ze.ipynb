# %%
import imageio
import matplotlib.pyplot as plt
import os
import numpy as np

plt.figure()
ax = plt.gca()
gif_path = "/home/anirudhkailaje/Documents/01_UPenn/02_MEAM5170/03_FinalProject/report/Biped Hop/ppt/media/torso_1.gif"
animation = imageio.get_reader(gif_path)
frames = []
for i, frame in enumerate(animation):
    frames.append(frame)
# import cv2
# cropheight = 160
# cropwidth = 160
# h = cropheight
# w = cropwidth
# image = np.zeros((h, w*3, 3))
# for i, f in enumerate(frames):
#     f = f[320-(h//2):320+h//2,320-w//2:320+w//2,:3]
#     image[:,i*(w):(i+1)*(w)] = f
# cv2.imwrite("output.bmp", image)

# %%
fig = plt.figure()
plt.imshow(frames[-15])
plt.show()

# %%
cv2.imwrite("torso1.png", frames[-15])
# Out:
# True
