# %%
import os, numpy as np, matplotlib.pyplot as plt, pickle, pandas as pd
import torch

# %%
path = '/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/RemainingModels/models/'
losses = []
loss_names = []
for file in os.listdir(path):
    if 'loss' in file:
        losses.append(pickle.load(open(path+file, 'rb')))
        loss_names.append(file.split('.')[0])

# %%
loss_names
# Out:
# ['MIlosses', 'STTClosses', 'Rhythmlosses', 'Formlosses', 'HYPlosses']

# %%
for i in range(len(losses)):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    axes[0].plot(losses[i][0])
    axes[0].set_title('Training Loss')
    axes[1].plot(losses[i][1].cpu().numpy())
    axes[1].set_title('Validation Loss')
    axes[2].plot(losses[i][2])
    axes[2].set_title('Learning Rate')
    fig.suptitle(loss_names[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> axes[0].plot(losses[i][0])
#       <a href='vscode-notebook-cell:/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> axes[0].set_title('Training Loss')
# ----> <a href='vscode-notebook-cell:/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> axes[1].plot(losses[i][1].cpu().numpy())
#       <a href='vscode-notebook-cell:/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> axes[1].set_title('Validation Loss')
#       <a href='vscode-notebook-cell:/home/anirudhkailaje/Documents/01_UPenn/01_ESE5460/03_Project/src/ScratchPad.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> axes[2].plot(losses[i][2])
#
# AttributeError: 'list' object has no attribute 'cpu'

# %%
losses[0][1].
