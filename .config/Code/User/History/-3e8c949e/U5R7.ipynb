# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('2024A MEAM543 UAV Database  - Sheet1.csv', skiprows=1)
df.columns = [col.replace('/','').strip()
              .replace('\n', '_').replace(' ','_')
              .replace('[','').replace(']','')
               .replace('(','').replace(')','').replace("\"","") for col in df.columns.to_list()]
df
# Out:
#                      Aircraft_Name Last_Name_of_Person_Posting  \
# 0          Trinity F90\n(Unlocked)                    Kothmann
# 1                        Penguin C                    Kothmann
# 2                   RQ-12A Wasp IV                    Zaccaria
# 3                      MQ-4CTriton                    Zaccaria
# 4            Insitu Inc. Scaneagle                    Zaccaria
# ..                             ...                         ...
# 252                    RQ-11 Raven                      Aditya
# 253          IAI Heron (Machatz-1)                      Aditya
# 254  General Atomics MQ-20 Avenger                      Aditya
# 255                    ATLAS C4EYE                      VItale
# 256                            NaN                      Vitale
#
#                                                   Link  \
# 0    https://www.quantum-systems.com/project/trinit...
# 1    https://edgeautonomy.io/solutions/penguin-c/\n...
# 2    https://www.navair.navy.mil/product/Group-1-Sm...
# 3    https://www.navair.navy.mil/product/MQ-4C http...
# 4    https://www.navair.navy.mil/product/Close-Rang...
# ..                                                 ...
# 252  https://en.wikipedia.org/wiki/AeroVironment_RQ...
# 253            https://en.wikipedia.org/wiki/IAI_Heron
# 254  https://en.wikipedia.org/wiki/General_Atomics_...
# 255          https://en.wikipedia.org/wiki/Atlas_C4EYE
# 256                                                NaN
#
#                                                 Cost_$  \
# 0                                              $16,900
# 1                                             $433,000
# 2    $22 million for a package, not specified how many
# 3                                     $123-180 million
# 4                                         $3.2 million
# ..                                                 ...
# 252                                            $35,000
# 253                                         40 million
# 254                                       $100 million
# 255                                                NaN
# 256                                                NaN
#
#                                    Mission_Description  \
# 0                                  Agricultural Survey
# 1                                                  NaN
# 2                                                  NaN
# 3                              Persistent Maritime ISR
# 4    ISR (intelligence, survelliance and reconnaiss...
# ..                                                 ...
# 252  Low-Altitude Intelligence and Surveillance Mis...
# 253  Strategic reconnaissance and surveillance oper...
# 254  Intelligence collection, precision penetration...
# 255         Target detection, search-and-rescue, recon
# 256                                                NaN
#
#                                      Mission_Equipment  \
# 0    High-precision position measurement when combi...
# 1                                                  NaN
# 2                               EO/IR gimbaled cameras
# 3    unique and robust mission sensor suite that pr...
# 4    stabilized electro-optical and/or infrared cam...
# ..                                                 ...
# 252                                       EO/IR Camera
# 253  EO and IR sensors, thermal surveillance equipm...
# 254  weather radar, TCAS (Traffic Collision Avoidan...
# 255  Gyroscopic stabilisers and gimbal, laser illum...
# 256                                                NaN
#
#     Maximum_Takeoff_Weight_lb Empty_Weight_lb  \
# 0                          11             NaN
# 1                        49.6              22
# 2                        2.85            0.95
# 3               32,250 pounds           14945
# 4                          58     30.90–39.68
# ..                        ...             ...
# 252                       4.8             NaN
# 253                     2,535           617.3
# 254                     18200           11700
# 255                  5.29 lbs             NaN
# 256                       NaN             NaN
#
#                 Max_Payload_Weight_lb Max_Fuel__Battery_Weight_lb  ...  \
# 0                                1.54                         NaN  ...
# 1                                  20                         NaN  ...
# 2                                 NaN                         NaN  ...
# 3    3200 (internal)\n2400 (external)                         NaN  ...
# 4                                  11                         NaN  ...
# ..                                ...                         ...  ...
# 252                               NaN                         NaN  ...
# 253                               550                         NaN  ...
# 254                              6500                        7900  ...
# 255                               NaN                         NaN  ...
# 256                               NaN                         NaN  ...
#
#                                 Takeoff__Recovery_Type  \
# 0             VTOL (Props rotate to vertical position)
# 1                                  Catapult\nParachute
# 2               hand launched, stall dad stick landing
# 3    Fully autonomous takeoff/landing with crew of ...
# 4                superwedge launcher, skyhook retrival
# ..                                                 ...
# 252                 Hand-Launched; Autonomous Recovery
# 253                        Fixed tricycle landing gear
# 254                                                NaN
# 255                                      Hand-launched
# 256                                                NaN
#
#     Required_Runway_Distance_feet Max_Speed_kts Cruise_Speed_kts  \
# 0                               0           NaN               33
# 1                               0          62.2               40
# 2                             NaN            35            22-35
# 3                             NaN           320              NaN
# 4                             NaN            80            50-60
# ..                            ...           ...              ...
# 252                           NaN            44               17
# 253                           NaN           113              NaN
# 254                           NaN           400              350
# 255                           NaN         58.28              NaN
# 256                           NaN           NaN              NaN
#
#     Stall_Speed_kts Service_Ceiling_ft Cruise_Altitude_ft Wing_Area_ft^2  \
# 0               NaN                NaN                  0            3.3
# 1              25.3              16000               5000            8.5
# 2               NaN              10000                500            NaN
# 3               NaN              56000                NaN            NaN
# 4               NaN                NaN                NaN            NaN
# ..              ...                ...                ...            ...
# 252             NaN             14,000                NaN            NaN
# 253             NaN             30,000                NaN            NaN
# 254             NaN              50000                NaN           N/A
# 255             NaN              16404                NaN            NaN
# 256             NaN                NaN                NaN            NaN
#
#     Span__ft Length_feet
# 0       7.48         NaN
# 1      10.83         7.5
# 2        3.3         2.7
# 3      130.9        47.6
# 4         10         4.8
# ..       ...         ...
# 252      4.5           3
# 253     54.5        27.9
# 254       66          44
# 255     5.08        2.69
# 256      NaN         NaN
#
# [257 rows x 29 columns]

# %%
import re
def get_numbers(x):
    num_float = re.findall(r'\d+\.\d+', str(x))
    dec_float = re.findall(r'\d+', str(x))
    comma_seperated_dec = re.findall(r'\d+\,\d+', str(x))
    comma_seperated_float = re.findall(r'\d+\,\d+\.\d+', str(x))
    if num_float:
        return np.array([float(num) for num in num_float]).max()
    elif dec_float:
        return np.array([float(num) for num in dec_float]).max()
    elif comma_seperated_dec:
        return np.array([float(num.replace(',','')) for num in comma_seperated_dec]).max()
    elif comma_seperated_float:
        return np.array([float(num.replace(',','')) for num in comma_seperated_float]).max()
    else:
        return np.nan

# %%
df.Max_Payload_Weight_lb = df.Max_Payload_Weight_lb.apply(get_numbers)
df[(df.Max_Payload_Weight_lb > (3.3*0.75)) & (df.Max_Payload_Weight_lb < (3.3*1.25))]
# Out:
#                               Aircraft_Name Last_Name_of_Person_Posting  \
# 15                         RQ-4 Global Hawk                     Griffin
# 36                            DeltaQuad Pro                       Jiang
# 99                    Bluebird Aero Spylite                      Hajjar
# 133                                Zipline                         Musa
# 153                     Microdrone EASY ONE                       barge
# 181            Global Hawk Northrup Grumman                     x. yang
# 188                        RQ-4 Global Hawk                        Zhao
# 224  Believer 1960mm Aerial Survey Aircraft                Rudy Whitney
# 230                                  Nova 2                         Yun
#
#                                                   Link   Cost_$  \
# 15   https://www.af.mil/About-Us/Fact-Sheets/Displa...    $222M
# 36   https://www.deltaquad.com/resources/technical-...      NaN
# 99   https://www.militaryfactory.com/aircraft/detai...      NaN
# 133  https://en.wikipedia.org/wiki/Zipline_(drone_d...      NaN
# 153  https://www.microdrones.com/en/integrated-syst...   105000
# 181  https://en.wikipedia.org/wiki/Northrop_Grumman...     222M
# 188  https://www.af.mil/About-Us/Fact-Sheets/Displa...     131M
# 224  https://www.getfpv.com/believer-1960mm-aerial-...  $399.99
# 230                          https://shield.ai/nova-2/  $25,000
#
#                                    Mission_Description  \
# 15       High-Altitude and Long Endurance Intelligence
# 36   Inspection, mapping & surveying, \nreconnaissa...
# 99                        Intelligence, reconnaissance
# 133                             Drone delivery company
# 153                               Survey, area mapping
# 181                       serveillance, reconnaissance
# 188   High-altitude long-endurance (HALE) surveilla...
# 224       Industrial class aerial survey capabilities
# 230                       Mission planning and mapping
#
#                                      Mission_Equipment  \
# 15   Imagery and Signals Intelligence Sensors along...
# 36             RGB, multispectral & thermal/IR cameras
# 99                                             Cameras
# 133                                                NaN
# 153  Fully Integrated High Resolution LiDAR & Camer...
# 181  EO/infared sensors, MP-RTIP radar, Airborne Si...
# 188  Various payloads including EO/IR sensors, synt...
# 224  Detachable wings, ventral shock absorption, an...
# 230  prop guards, gps-denied flight, thermal camera...
#
#     Maximum_Takeoff_Weight_lb Empty_Weight_lb  Max_Payload_Weight_lb  \
# 15                     32,250          14,950                   3.00
# 36                       13.7             7.3                   2.65
# 99                         20              15                   4.00
# 133                       NaN              44                   4.00
# 153                        13              10                   3.00
# 181                     32250          15,000                   3.00
# 188                    32,250          14,950                   3.00
# 224                      12.1             9.3                   2.80
# 230                        24              20                   4.00
#
#              Max_Fuel__Battery_Weight_lb  ...  \
# 15                                17,300  ...
# 36                                  3.75  ...
# 99                                   NaN  ...
# 133                                  NaN  ...
# 153                                 4.62  ...
# 181                                14000  ...
# 188                                  NaN  ...
# 224  Depends (multiple battery options)   ...
# 230                                  NaN  ...
#
#                                 Takeoff__Recovery_Type  \
# 15                                      Remote Piloted
# 36                                                VTOL
# 99                                           Slingshot
# 133  Takeoff via launch linear rail, Recovered via net
# 153                                               VTOL
# 181                                       conventional
# 188                                Conventional runway
# 224                                                NaN
# 230                                               VTOL
#
#     Required_Runway_Distance_feet Max_Speed_kts Cruise_Speed_kts  \
# 15                            NaN           NaN              310
# 36                            NaN            54               35
# 99                            NaN            65              NaN
# 133                             0           NaN             54.5
# 153                           NaN           NaN              NaN
# 181                          8000           340              310
# 188                           NaN           357              310
# 224                           NaN           NaN             38.9
# 230                             0            19               30
#
#     Stall_Speed_kts Service_Ceiling_ft Cruise_Altitude_ft Wing_Area_ft^2  \
# 15              NaN             60,000                NaN            NaN
# 36               23              13000                NaN            9.7
# 99              NaN              3,281              3,000            NaN
# 133             NaN                390                NaN            NaN
# 153             NaN                NaN                984            NaN
# 181             NaN             60,000              55000           1410
# 188             NaN              60000              50000            NaN
# 224            19.5                NaN                NaN            NaN
# 230             NaN                NaN                NaN            NaN
#
#     Span__ft Length_feet
# 15       131        47.6
# 36       7.7        2.95
# 99         9           4
# 133       11         NaN
# 153      3.1         3.1
# 181      130          48
# 188     47.6       130.9
# 224     6.43         NaN
# 230      NaN         3.2
#
# [9 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['Aircraft_Name', 'Last_Name_of_Person_Posting', 'Link', 'Cost_$',
#        'Mission_Description', 'Mission_Equipment', 'Maximum_Takeoff_Weight_lb',
#        'Empty_Weight_lb', 'Max_Payload_Weight_lb',
#        'Max_Fuel__Battery_Weight_lb', 'Fuel_Type_Elec__Gas',
#        'Number_of_Batteries', 'Battery_Voltage_Volts',
#        'Battery_Capacity_Amp-Hours', 'Number_of_Engines',
#        'Sea-Level_Thrust_per_Engine_lbf', 'Sea-Level_Power_per_Engine_hp',
#        'Endurance_hrs', 'Max_Flight_Distance_Range_miles',
#        'Takeoff__Recovery_Type', 'Required_Runway_Distance_feet',
#        'Max_Speed_kts', 'Cruise_Speed_kts', 'Stall_Speed_kts',
#        'Service_Ceiling_ft', 'Cruise_Altitude_ft', 'Wing_Area_ft^2',
#        'Span__ft', 'Length_feet'],
#       dtype='object')

# %%
df.Max_Flight_Distance_"Range_miles
